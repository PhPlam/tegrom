# %%
import pandas as pd

data = pd.read_csv('/home/philipp/Desktop/trends.csv')

# %%
data
# Out:
#        intensity_trend
# 0             0.937997
# 1             1.021207
# 2             0.809211
# 3             1.083551
# 4             1.027027
# ...                ...
# 79944         1.137815
# 79945         0.907029
# 79946         0.949501
# 79947         0.978197
# 79948         0.955556
#
# [79949 rows x 1 columns]

# %%
upper_limit = 1.025
lower_limit = 0.975

uweight_1 = upper_limit * 1.1
uweight_2 = upper_limit * 1.2
uweight_3 = upper_limit * 1.3
uweight_4 = upper_limit * 1.4
uweight_5 = upper_limit * 1.5
uweight_6 = upper_limit * 1.6

print(data[data['intensity_trend'] >= upper_limit])

print(uweight_1)
data_1 = data[data['intensity_trend'] >= upper_limit]
data_1 = data_1[data_1['intensity_trend'] < uweight_1]
print(data_1)
print("\n")

print(uweight_2)
data_2 = data[data['intensity_trend'] >= uweight_1]
data_2 = data_2[data_2['intensity_trend'] < uweight_2]
print(data_2)
print("\n")

print(uweight_3)
data_3 = data[data['intensity_trend'] >= uweight_2]
data_3 = data_3[data_3['intensity_trend'] < uweight_3]
print(data_3)
print("\n")

print(uweight_4)
data_4 = data[data['intensity_trend'] >= uweight_3]
data_4 = data_4[data_4['intensity_trend'] < uweight_4]
print(data_4)
print("\n")

print(uweight_5)
data_5 = data[data['intensity_trend'] >= uweight_4]
data_5 = data_5[data_5['intensity_trend'] < uweight_5]
print(data_5)
print("\n")

print(uweight_6)
data_6 = data[data['intensity_trend'] >= uweight_5]
data_6 = data_6[data_6['intensity_trend'] < uweight_6]
print(data_6)
print("\n")

data_7 = data[data['intensity_trend'] >= uweight_6]
print(data_7)
#print(data[data['intensity_trend'] > weight])
#print(data[data['intensity_trend'] > weight])
# Out:
#        intensity_trend
# 3             1.083551
# 4             1.027027
# 5             1.027027
# 7             1.223276
# 8             1.223276
# ...                ...
# 79918         1.162466
# 79919         1.150000
# 79935         1.168691
# 79943         1.066024
# 79944         1.137815
#
# [30181 rows x 1 columns]
# 1.1275
#        intensity_trend
# 3             1.083551
# 4             1.027027
# 5             1.027027
# 10            1.092188
# 19            1.082668
# ...                ...
# 79907         1.073129
# 79908         1.071641
# 79915         1.061224
# 79916         1.063075
# 79943         1.066024
#
# [15255 rows x 1 columns]
#
#
# 1.2299999999999998
#        intensity_trend
# 7             1.223276
# 8             1.223276
# 14            1.166320
# 18            1.148496
# 35            1.158645
# ...                ...
# 79914         1.185654
# 79918         1.162466
# 79919         1.150000
# 79935         1.168691
# 79944         1.137815
#
# ...

# %%
tdata = data[data['intensity_trend'] < upper_limit]
tdata = tdata[tdata['intensity_trend'] > lower_limit]
print(tdata)
# Out:
#        intensity_trend
# 1             1.021207
# 16            1.014898
# 27            0.977236
# 37            1.021046
# 38            1.021046
# ...                ...
# 79928         1.014975
# 79933         0.990667
# 79934         0.977099
# 79938         0.976977
# 79947         0.978197
#
# [10955 rows x 1 columns]

# %%
lweight_1 = lower_limit * 0.9
lweight_2 = lower_limit * 0.8
lweight_3 = lower_limit * 0.7
lweight_4 = lower_limit * 0.6
lweight_5 = lower_limit * 0.5
lweight_6 = lower_limit * 0.4

print(data[data['intensity_trend'] <= lower_limit])
print("\n")

print(lweight_1)
data11 = data[data['intensity_trend'] <= lower_limit]
data11 = data11[data11['intensity_trend'] > lweight_1]
print(data11)
print("\n")

print(lweight_2)
data12 = data[data['intensity_trend'] <= lweight_1]
data12 = data12[data12['intensity_trend'] > lweight_2]
print(data12)
print("\n")

print(lweight_3)
data13 = data[data['intensity_trend'] <= lweight_2]
data13 = data13[data13['intensity_trend'] > lweight_3]
print(data13)
print("\n")

print(lweight_4)
data14 = data[data['intensity_trend'] <= lweight_3]
data14 = data14[data14['intensity_trend'] > lweight_4]
print(data14)
print("\n")

print(lweight_5)
data15 = data[data['intensity_trend'] <= lweight_4]
data15 = data15[data15['intensity_trend'] > lweight_5]
print(data15)
print("\n")

print(lweight_6)
data16 = data[data['intensity_trend'] <= lweight_5]
data16 = data16[data16['intensity_trend'] > lweight_6]
print(data16)
print("\n")

data17 = data[data['intensity_trend'] <= lweight_6]
print(data17)
# Out:
#        intensity_trend
# 0             0.937997
# 2             0.809211
# 6             0.812844
# 9             0.940148
# 11            0.967302
# ...                ...
# 79941         0.666667
# 79942         0.718310
# 79945         0.907029
# 79946         0.949501
# 79948         0.955556
#
# [38813 rows x 1 columns]
#
#
# 0.8775
#        intensity_trend
# 0             0.937997
# 9             0.940148
# 11            0.967302
# 12            0.967302
# 15            0.934865
# ...                ...
# 79922         0.967290
# 79926         0.943372
# 79945         0.907029
# 79946         0.949501
# 79948         0.955556
#
# [19626 rows x 1 columns]
#
#
# 0.78
#        intensity_trend
# 2             0.809211
# 6             0.812844
# 17            0.859259
# 29            0.805915
# 49            0.839462
# ...                ...
# 79932         0.811054
# 79936         0.876833
# 79937         0.846591
# 79939         0.817590
# 79940         0.797468
#
# ...
