# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('/home/philipp/github/neoscripts/models/files_for_model/increasing_intensities.csv', sep=',')

# %%
df
# Out:
#              to_molecule  from_mid  to_mid      from_molecule  C  H  O  N  S  \
# 0          C14 H13 N1 O4      7803    7809      C14 H11 N1 O3  0  2  1  0  0
# 1             C14 H10 O4      7803    7809      C14 H11 N1 O3  0 -1  1 -1  0
# 2          C14 H11 N1 O4      7803    7809      C14 H11 N1 O3  0  0  1  0  0
# 3             C18 H14 O4      7803    7809         C19 H14 O4 -1  0  0  0  0
# 4             C19 H12 O4      7803    7809         C19 H14 O4  0 -2  0  0  0
# ...                  ...       ...     ...                ... .. .. .. .. ..
# 99767  C22 H34 N2 O11 S3      7868    7874  C23 H36 N2 O11 S3 -1 -2  0  0  0
# 99768        C33 H36 O14      7868    7874        C35 H40 O15 -2 -4 -1  0  0
# 99769        C34 H40 O13      7868    7874        C35 H40 O15 -1  0 -2  0  0
# 99770        C34 H40 O15      7868    7874        C35 H40 O15 -1  0  0  0  0
# 99771        C34 H38 O16      7868    7874        C35 H40 O15 -1 -2  1  0  0
#
# ...
